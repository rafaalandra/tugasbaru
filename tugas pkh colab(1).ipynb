# %%
import numpy as np
import pandas as pd

# %%
#Panggil data drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the dataset
data = pd.read_csv("/content/drive/MyDrive/visualisasi/data pkh1.csv")

# %%
data.head(23)
# Out:
#    Fatmawati;Tidak Mampu;48 Tahun;Tidak;Ada;Tidak;Tidak;Tidak;Penerima
# 0   Sumarni;Tidak Mampu;54 Tahun;Tidak;Ada;Tidak;T...
# 1   Hajrah;Tidak Mampu;50 Tahun;Tidak;Tidak ada;Ti...
# 2   Ratna;Tidak Mampu;45 Tahun;Tidak;Ada;Tidak;Tid...
# 3   Nurma;Tidak Mampu;35 Tahun;Ada;Ada;Tidak;Tidak...
# 4   Jawariah;Tidak Mampu;70 Tahun;Tidak;Tidak ada;...
# 5   Nursani;Tidak Mampu;48 T ahun;Tidak;Ada;Tidak;...
# 6   Sri;Tidak Mampu;50 Tahun;Ada;Ada;Tidak;Tidak;T...
# 7   Nurmi;Tidak Mampu;30 Tahun;Ada;Ada;Tidak;Tidak...
# 8   Nazmah;Tidak Mampu;48 Tahun;Tidak;Ada;Tidak;Ti...
# 9   Suryati;Tidak Mampu;47 Tahun;Tidak;Ada;Tidak;T...
# 10  Mustamin;Tidak Mampu;70 Tahun;Tidak;Tidak ada;...
# 11  Kartika;Tidak Mampu;35 Tahun;Ada;Ada;Tidak;Tid...
# 12  Abdullah;Tidak Mampu;50 Tahun;Tidak;Tidak ada;...
# 13  Amrullah;Tidak Mampu;50 Tahun;Tidak;Ada;Tidak;...
# 14  Masita;Mampu;52 Tahun;Tidak;Ada;Tidak;Tidak;Ti...
# 15  Siti Hadijah;Mampu;60 Tahun;Tidak;Tidak ada;Ti...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(data.columns.tolist())
# Out:
# [';Nama;Status;umur;Usia Dini;Anak Sekolah;Ibu Hamil;Lansia;Disabilitas;Kelayakan']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat DataFrame dari dataset
data = {
    "Umur": [48, 54, 50, 45, 35, 70, 48, 50, 30, 48, 47, 70, 35, 50, 50, 52, 60, 38, 29, 55, 52, 33, 58],
    "Usia Dini": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Ada', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak'],
    "Anak Sekolah": ['Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Tidak ada', 'Ada', 'Tidak ada'],
    "Ibu Hamil": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Lansia": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Disabilitas": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Kelayakan": ['Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima']
}

df = pd.DataFrame(data)

# Membuat distribusi ganda
plt.figure(figsize=(10, 6))
sns.countplot(x='Umur', hue='Kelayakan', data=df, palette='Set2')

# Menambahkan label dan judul
plt.title('Distribusi Umur Berdasarkan Kelayakan')
plt.xlabel('Umur')
plt.ylabel('Jumlah')

# Menampilkan plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat DataFrame dari dataset
data = {
    "Umur": [48, 54, 50, 45, 35, 70, 48, 50, 30, 48, 47, 70, 35, 50, 50, 52, 60, 38, 29, 55, 52, 33, 58],
    "Usia Dini": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Ada', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak'],
    "Anak Sekolah": ['Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Tidak ada', 'Ada', 'Tidak ada'],
    "Ibu Hamil": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Lansia": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Disabilitas": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Kelayakan": ['Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima']
}

df = pd.DataFrame(data)

# Menyusun plot untuk melihat korelasi antar variabel kategorikal dan "Kelayakan"
plt.figure(figsize=(14, 10))

# Plot untuk "Usia Dini" vs "Kelayakan"
plt.subplot(2, 3, 1)
sns.countplot(x='Usia Dini', hue='Kelayakan', data=df, palette='Set2')
plt.title('Usia Dini vs Kelayakan')

# Plot untuk "Anak Sekolah" vs "Kelayakan"
plt.subplot(2, 3, 2)
sns.countplot(x='Anak Sekolah', hue='Kelayakan', data=df, palette='Set2')
plt.title('Anak Sekolah vs Kelayakan')

# Plot untuk "Ibu Hamil" vs "Kelayakan"
plt.subplot(2, 3, 3)
sns.countplot(x='Ibu Hamil', hue='Kelayakan', data=df, palette='Set2')
plt.title('Ibu Hamil vs Kelayakan')

# Plot untuk "Lansia" vs "Kelayakan"
plt.subplot(2, 3, 4)
sns.countplot(x='Lansia', hue='Kelayakan', data=df, palette='Set2')
plt.title('Lansia vs Kelayakan')

# Plot untuk "Disabilitas" vs "Kelayakan"
plt.subplot(2, 3, 5)
sns.countplot(x='Disabilitas', hue='Kelayakan', data=df, palette='Set2')
plt.title('Disabilitas vs Kelayakan')

# Menyesuaikan layout
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data yang sudah disediakan
data = {
    "Umur": ['48 Tahun', '54 Tahun', '50 Tahun', '45 Tahun', '35 Tahun', '70 Tahun', '48 Tahun', '50 Tahun', '30 Tahun', '48 Tahun',
             '47 Tahun', '70 Tahun', '35 Tahun', '50 Tahun', '50 Tahun', '52 Tahun', '60 Tahun', '38 Tahun', '29 Tahun', '55 Tahun',
             '52 Tahun', '33 Tahun', '58 Tahun'],
    "Usia Dini": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Ada', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada',
                  'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak'],
    "Anak Sekolah": ['Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Tidak ada',
                     'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Tidak ada', 'Ada', 'Tidak ada'],
    "Ibu Hamil": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak',
                  'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Lansia": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak',
               'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Disabilitas": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak',
                    'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Kelayakan": ['Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima',
                  'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Bukan penerima', 'Bukan penerima',
                  'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima']
}

df = pd.DataFrame(data)

# Mengonversi umur dari format string menjadi angka
df['Umur'] = df['Umur'].str.split().str[0].astype(int)

# Visualisasi Korelasi antara Umur dan Kelayakan dengan boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Kelayakan', y='Umur', data=df, palette='Set2')

# Menambahkan label dan judul
plt.title('Korelasi Umur dengan Kelayakan')
plt.xlabel('Kelayakan')
plt.ylabel('Umur')

# Menampilkan plot
plt.tight_layout()
plt.show()

# Jika ingin scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Umur', y='Kelayakan', data=df, palette='Set2')

# Menambahkan label dan judul
plt.title('Korelasi Umur dengan Kelayakan (Scatter Plot)')
plt.xlabel('Umur')
plt.ylabel('Kelayakan')

# Menampilkan plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-53-7c73b035133e>:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Kelayakan', y='Umur', data=df, palette='Set2')
# <ipython-input-53-7c73b035133e>:45: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Umur', y='Kelayakan', data=df, palette='Set2')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat DataFrame dari dataset
data = {
    "Umur": [48, 54, 50, 45, 35, 70, 48, 50, 30, 48, 47, 70, 35, 50, 50, 52, 60, 38, 29, 55, 52, 33, 58],
    "Usia Dini": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Ada', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak'],
    "Anak Sekolah": ['Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Tidak ada', 'Ada', 'Tidak ada'],
    "Ibu Hamil": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Lansia": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Disabilitas": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Kelayakan": ['Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima']
}

df = pd.DataFrame(data)

# Plot korelasi antara 'Usia Dini' dan 'Kelayakan'
plt.figure(figsize=(10, 6))
sns.countplot(x='Usia Dini', hue='Kelayakan', data=df, palette='Set1')

# Menambahkan label dan judul
plt.title('Korelasi antara Usia Dini dan Kelayakan')
plt.xlabel('Usia Dini')
plt.ylabel('Jumlah')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat DataFrame dari dataset
data = {
    "Umur": [48, 54, 50, 45, 35, 70, 48, 50, 30, 48, 47, 70, 35, 50, 50, 52, 60, 38, 29, 55, 52, 33, 58],
    "Usia Dini": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Ada', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak'],
    "Anak Sekolah": ['Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Tidak ada', 'Ada', 'Tidak ada'],
    "Ibu Hamil": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Lansia": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Disabilitas": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Kelayakan": ['Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima']
}

df = pd.DataFrame(data)

# Membuat countplot untuk korelasi antara Kelayakan dan Anak Sekolah
plt.figure(figsize=(10, 6))
sns.countplot(x='Anak Sekolah', hue='Kelayakan', data=df, palette='Set1')

# Menambahkan label dan judul
plt.title('Korelasi antara Anak Sekolah dan Kelayakan')
plt.xlabel('Anak Sekolah')
plt.ylabel('Jumlah')

# Menampilkan plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat DataFrame dari dataset
data = {
    "Umur": [48, 54, 50, 45, 35, 70, 48, 50, 30, 48, 47, 70, 35, 50, 50, 52, 60, 38, 29, 55, 52, 33, 58],
    "Usia Dini": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Ada', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak'],
    "Anak Sekolah": ['Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Tidak ada', 'Ada', 'Tidak ada'],
    "Ibu Hamil": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Lansia": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Disabilitas": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Kelayakan": ['Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima']
}

df = pd.DataFrame(data)

# Membuat plot korelasi antara Kelayakan dan Ibu Hamil
plt.figure(figsize=(10, 6))
sns.countplot(x='Ibu Hamil', hue='Kelayakan', data=df, palette='Set1')

# Menambahkan label dan judul
plt.title('Korelasi Antara Kelayakan dan Ibu Hamil')
plt.xlabel('Ibu Hamil')
plt.ylabel('Jumlah')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat DataFrame dari dataset
data = {
    "Umur": [48, 54, 50, 45, 35, 70, 48, 50, 30, 48, 47, 70, 35, 50, 50, 52, 60, 38, 29, 55, 52, 33, 58],
    "Usia Dini": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Ada', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak'],
    "Anak Sekolah": ['Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Tidak ada', 'Ada', 'Tidak ada'],
    "Ibu Hamil": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Lansia": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Disabilitas": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Kelayakan": ['Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima']
}

df = pd.DataFrame(data)

# Menggunakan countplot untuk memvisualisasikan korelasi antara 'Kelayakan' dan 'Lansia'
plt.figure(figsize=(10, 6))
sns.countplot(x='Lansia', hue='Kelayakan', data=df, palette='Set1')

# Menambahkan label dan judul
plt.title('Korelasi antara Kelayakan dan Lansia')
plt.xlabel('Lansia')
plt.ylabel('Jumlah')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset yang sudah ada
data = {
    "Umur": [48, 54, 50, 45, 35, 70, 48, 50, 30, 48, 47, 70, 35, 50, 50, 52, 60, 38, 29, 55, 52, 33, 58],
    "Usia Dini": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Ada', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak'],
    "Anak Sekolah": ['Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Ada', 'Ada', 'Tidak ada', 'Tidak ada', 'Ada', 'Tidak ada'],
    "Ibu Hamil": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Lansia": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ya', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Disabilitas": ['Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Ada', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak', 'Tidak'],
    "Kelayakan": ['Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima', 'Bukan penerima']
}

df = pd.DataFrame(data)

# Membuat plot untuk korelasi antara "Kelayakan" dan "Disabilitas"
plt.figure(figsize=(10, 6))
sns.countplot(x='Disabilitas', hue='Kelayakan', data=df, palette='Set2')

# Menambahkan label dan judul
plt.title('Distribusi Disabilitas Berdasarkan Kelayakan')
plt.xlabel('Disabilitas')
plt.ylabel('Jumlah')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
contingency_table = pd.crosstab(data['Label'], data['Gender'])
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-square Test between Label and Gender:\nChi2 = {chi2}, p-value = {p}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-f88e1a856d2b> in <cell line: 1>()
# ----> 1 contingency_table = pd.crosstab(data['Label'], data['Gender'])
#       2 chi2, p, dof, expected = chi2_contingency(contingency_table)
#       3 print(f"Chi-square Test between Label and Gender:\nChi2 = {chi2}, p-value = {p}")
#
# KeyError: 'Label'
